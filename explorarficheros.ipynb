# %%
import pandas as pd

# %%
cruces = pd.read_csv('cruces.csv', sep=';', encoding='latin-1')
direcciones = pd.read_csv('direcciones.csv', sep=';', encoding='latin-1', low_memory=False)

# %%
cruces.head(20)
# Out:
#     Codigo de vía tratado                  Literal completo del vial tratado  \
# 0                     127  CALLE DE ISABEL COLBRAND                      ...
# 1                     127  CALLE DE ISABEL COLBRAND                      ...
# 2                     127  CALLE DE ISABEL COLBRAND                      ...
# 3                     127  CALLE DE ISABEL COLBRAND                      ...
# 4                     127  CALLE DE ISABEL COLBRAND                      ...
# 5                     127  CALLE DE ISABEL COLBRAND                      ...
# 6                     150  CALLE DE GONZÁLEZ DÁVILA                      ...
# 7                     150  CALLE DE GONZÁLEZ DÁVILA                      ...
# 8                     150  CALLE DE GONZÁLEZ DÁVILA                      ...
# 9                     150  CALLE DE GONZÁLEZ DÁVILA                      ...
# 10                    200  CALLE DE LA ABADA                             ...
# 11                    200  CALLE DE LA ABADA                             ...
# 12                    200  CALLE DE LA ABADA                             ...
# 13                    200  CALLE DE LA ABADA                             ...
# 14                    300  CALLE DE LOS ABADES                           ...
# 15                    300  CALLE DE LOS ABADES                           ...
# 16                    300  CALLE DE LOS ABADES                           ...
# 17                    400  CALLE DE LA ABADESA                           ...
# 18                    400  CALLE DE LA ABADESA                           ...
# 19                    400  CALLE DE LA ABADESA                           ...
#
#      Clase de la via tratado Particula de la via tratado  \
# 0   CALLE                                         DE
# 1   CALLE                                         DE
# 2   CALLE                                         DE
# 3   CALLE                                         DE
# 4   CALLE                                         DE
# 5   CALLE                                         DE
# 6   CALLE                                         DE
# 7   CALLE                                         DE
# 8   CALLE                                         DE
# 9   CALLE                                         DE
# 10  CALLE                                         DE LA
# 11  CALLE                                         DE LA
# 12  CALLE                                         DE LA
# 13  CALLE                                         DE LA
# 14  CALLE                                         DE LOS
# 15  CALLE                                         DE LOS
# 16  CALLE                                         DE LOS
# 17  CALLE                                         DE LA
# 18  CALLE                                         DE LA
# 19  CALLE                                         DE LA
#
#                             Nombre de la via tratado  \
# 0   ISABEL COLBRAND
# 1   ISABEL COLBRAND
# 2   ISABEL COLBRAND
# 3   ISABEL COLBRAND
# 4   ISABEL COLBRAND
# 5   ISABEL COLBRAND
# 6   GONZALEZ DAVILA
# 7   GONZALEZ DAVILA
# 8   GONZALEZ DAVILA
# 9   GONZALEZ DAVILA
# 10  ABADA
# 11  ABADA
# 12  ABADA
# 13  ABADA
# 14  ABADES
# 15  ABADES
# 16  ABADES
# 17  ABADESA
# 18  ABADESA
# 19  ABADESA
#
#     Codigo de via que cruza o enlaza  \
# 0                               2792
# 1                               1837
# 2                              87100
# 3                               2793
# 4                               2794
# 5                             313425
# 6                             789500
# 7                               2275
# 8                             364900
# 9                             319000
# 10                            656500
# 11                            505100
# 12                            202800
# 13                            342950
# 14                            789100
# 15                            262000
# 16                            505000
# 17                            643000
# 18                             86600
# 19                            538100
#
#                   Literal completo del vial que cruza  \
# 0   CALLE DE CASTIELLO DE JACA                    ...
# 1   CALLE DE FEDERICO MOMPOU                      ...
# 8                               446986420               3º38'19.56'' W
# 9                               447000847               3º38'21.51'' W
# 10                              447469007               3º42'13.48'' W
# 11                              447475670               3º42'15.88'' W
# 12                              447484720               3º42'17.48'' W
# 13                              447484720               3º42'17.48'' W
# 14                              446861668               3º41'57.01'' W
# 15                              447368114               3º42'22.0'' W
# 16                              447374737               3º42'15.96'' W
# 17                              447975862               3º42'15.45'' W
# 18                              447979914               3º42'15.38'' W
# 19                              447979914               3º42'15.38'' W
#
#    Latitud en S R  WGS84 (cruce)
# 0               40º30'36.13'' N
# 1               40º30'36.13'' N
# 2               40º30'40.98'' N
# 3               40º30'46.21'' N
# 4               40º30'52.83'' N
# 5               40º30'56.72'' N
# 6               40º22'23.65'' N
# 7               40º22'27.82'' N
# 8               40º22'32.61'' N
# 9               40º22'37.27'' N
# 10              40º25'7.77'' N
# 11              40º25'9.93'' N
# 12              40º25'12.84'' N
# 13              40º25'12.84'' N
# 14              40º21'50.91'' N
# 15              40º24'34.99'' N
# 16              40º24'37.17'' N
# 17              40º27'52.16'' N
# 18              40º27'53.46'' N
# 19              40º27'53.46'' N

# %%
# vamos a buscar rotondas
df_rotondas = cruces.loc[cruces['Clase de la via que cruza'] == 'ROTONDA']

# %%
df_rotondas.head()
# Out:
# Empty DataFrame
# Columns: [Codigo de vía tratado, Literal completo del vial tratado, Clase de la via tratado, Particula de la via tratado, Nombre de la via tratado, Codigo de via que cruza o enlaza, Literal completo del vial que cruza, Clase de la via que cruza, Particula de la via que cruza, Nombre de la via que cruza, Coordenada X (Guia Urbana) cm (cruce), Coordenada Y (Guia Urbana) cm (cruce), Longitud en S R  WGS84 (cruce), Latitud en S R  WGS84 (cruce)]
# Index: []

# %%
direcciones.head(20)
# Out:
#     Codigo de numero  Codigo de via           Clase de la via  \
# 0           31031089       31001337  AUTOVIA
# 1           31031088       31001337  AUTOVIA
# 2           31031091       31001337  AUTOVIA
# 3           31031090       31001337  AUTOVIA
# 4           31031093       31001337  AUTOVIA
# 5           31031092       31001337  AUTOVIA
# 6           31031096       31001337  AUTOVIA
# 7           31031095       31001337  AUTOVIA
# 8           31031053       31001336  AUTOVIA
# 9           31031052       31001336  AUTOVIA
# 10          31031059       31001336  AUTOVIA
# 11          31031056       31001336  AUTOVIA
# 12          31031065       31001336  AUTOVIA
# 13          31031063       31001336  AUTOVIA
# 14          31031067       31001336  AUTOVIA
# 15          31031066       31001336  AUTOVIA
# 16          31031070       31001336  AUTOVIA
# 17          31031069       31001336  AUTOVIA
# 18          31031072       31001336  AUTOVIA
# 19          31031071       31001336  AUTOVIA
#
#    Partï¿½cula de la vï¿½a                                Nombre de la vï¿½a  \
# 0                           A-1
# 1                           A-1
# 2                           A-1
# 3                           A-1
# 4                           A-1
# 5                           A-1
# 6                           A-1
# 7                           A-1
# 8                           A-2
# 9                           A-2
# 10                          A-2
# 11                          A-2
# 12                          A-2
# 13                          A-2
# 14                          A-2
# 15                          A-2
# 16                          A-2
# 17                          A-2
# 18                          A-2
# 19                          A-2
#
#    Literal de numeracion  Codigo de distrito   Nombre del distrito  \
# 0            KM.001000EN                   8  FUENCARRAL-EL PARDO
# 1            KM.001000SA                  16  HORTALEZA
# 2            KM.001100EN                   8  FUENCARRAL-EL PARDO
# 3            KM.001100SA                  16  HORTALEZA
# 4            KM.001200EN                   8  FUENCARRAL-EL PARDO
# 5            KM.001200SA                  16  HORTALEZA
# 6            KM.001300EN                   8  FUENCARRAL-EL PARDO
# 7            KM.001300SA                  16  HORTALEZA
# 8            KM.000500EN                  15  CIUDAD LINEAL
# 9            KM.000500SA                  15  CIUDAD LINEAL
# 10           KM.000600EN                  16  HORTALEZA
# 11           KM.000600SA                  20  SAN BLAS-CANILLEJAS
# 12           KM.000700EN                  16  HORTALEZA
# 13           KM.000700SA                  20  SAN BLAS-CANILLEJAS
# 14           KM.000800EN                  16  HORTALEZA
# 15           KM.000800SA                  20  SAN BLAS-CANILLEJAS
# 16           KM.000900EN                  16  HORTALEZA
# 17           KM.000900SA                  20  SAN BLAS-CANILLEJAS
# 18           KM.001000EN                  21  BARAJAS
# 19           KM.001000SA                  20  SAN BLAS-CANILLEJAS
#
#     Codigo de barrio     Nombre del barrio  ...  \
# 0                  6  VALVERDE              ...
# 1                  6  VALDEFUENTES          ...
# 2                  6  VALVERDE              ...
# 3                  6  VALDEFUENTES          ...
# 4                  6  VALVERDE              ...
# 5                  6  VALDEFUENTES          ...
# 6                  6  VALVERDE              ...
# 7                  6  VALDEFUENTES          ...
# 8                  6  SAN JUAN BAUTISTA     ...
# 9                  5  SAN PASCUAL           ...
# 10                 2  PIOVERA               ...
# 11                 8  EL SALVADOR           ...
# 12                 2  PIOVERA               ...
# 13                 8  EL SALVADOR           ...
# 14                 1  PALOMAS               ...
# 15                 7  CANILLEJAS            ...
# 16                 1  PALOMAS               ...
# 17                 7  CANILLEJAS            ...
# 18                 1  ALAMEDA DE OSUNA      ...
# 19                 6  REJAS                 ...
#
#     Coordenada X (Guia Urbana) cm  Coordenada Y (Guia Urbana) cm  \
# 0                        44305633                      448250340
# 1                        44312246                      448249077
# 2                        44367522                      448330933
# 3                        44373755                      448325151
# 4                        44425207                      448408185
# 5                        44433081                      448404503
# 6                        44438526                      448495442
# 7                        44442063                      448497941
# 8                        44469993                      447782563
# 9                        44471548                      447779654
# 10                       44558576                      447805791
# 11                       44557997                      447802578
# 12                       44655346                      447804210
# 13                       44655780                      447801101
# 14                       44757023                      447808120
# 15                       44757294                      447804961
# 16                       44852558                      447806898
# 17                       44852621                      447803677
# 18                       44954935                      447811092
# 19                       44954972                      447807767
#
#    Longitud en S R  ETRS89 WGS84  Latitud en S R  ETRS89 WGS84  \
# 0             3ï¿½40'23.6'' W               40ï¿½29'21.82'' N
# 1             3ï¿½40'20.75'' W              40ï¿½29'21.45'' N
# 2             3ï¿½39'57.57'' W              40ï¿½29'48.11'' N
# 3             3ï¿½39'54.87'' W              40ï¿½29'46.28'' N
# 4             3ï¿½39'33.3'' W               40ï¿½30'13.32'' N
# 5             3ï¿½39'29.94'' W              40ï¿½30'12.14'' N
# 6             3ï¿½39'27.93'' W              40ï¿½30'41.63'' N
# 7             3ï¿½39'26.41'' W              40ï¿½30'42.45'' N
# 8             3ï¿½39'12.3'' W               40ï¿½26'50.54'' N
# 9             3ï¿½39'11.61'' W              40ï¿½26'49.61'' N
# 10            3ï¿½38'34.76'' W              40ï¿½26'58.28'' N
# 11            3ï¿½38'35.01'' W              40ï¿½26'57.24'' N
# 12            3ï¿½37'53.67'' W              40ï¿½26'57.98'' N
# 13            3ï¿½37'53.49'' W              40ï¿½26'56.98'' N
# 14            3ï¿½37'10.55'' W              40ï¿½26'59.48'' N
# 15            3ï¿½37'10.41'' W              40ï¿½26'58.48'' N
# 16            3ï¿½36'29.96'' W              40ï¿½26'59.31'' N
# 17            3ï¿½36'29.95'' W              40ï¿½26'58.27'' N
# 18            3ï¿½35'46.54'' W              40ï¿½27'0.9'' N
# 19            3ï¿½35'46.49'' W              40ï¿½26'59.83'' N
#
#     Tipo de la via a la que pertenece el numero  \
# 0                             Topï¿½nimo
# 1                             Topï¿½nimo
# 2                             Topï¿½nimo
# 3                             Topï¿½nimo
# 4                             Topï¿½nimo
# 5                             Topï¿½nimo
# 6                             Topï¿½nimo
# 7                             Topï¿½nimo
# 8                             Topï¿½nimo
# 9                             Topï¿½nimo
# 10                            Topï¿½nimo
# 11                            Topï¿½nimo
# 12                            Topï¿½nimo
# 13                            Topï¿½nimo
# 14                            Topï¿½nimo
# 15                            Topï¿½nimo
# 16                            Topï¿½nimo
# 17                            Topï¿½nimo
# 18                            Topï¿½nimo
# 19                            Topï¿½nimo
#
#    Situacion de la via respecto al terreno  Tipo de denominacion de la via  \
# 0                              Nivel                                 Admon
# 1                              Nivel                                 Admon
# 2                              Nivel                                 Admon
# 3                              Nivel                                 Admon
# 4                              Nivel                                 Admon
# 5                              Nivel                                 Admon
# 6                              Nivel                                 Admon
# 7                              Nivel                                 Admon
# 8                              Nivel                                 Admon
# 9                              Nivel                                 Admon
# 10                             Nivel                                 Admon
# 11                             Nivel                                 Admon
# 12                             Nivel                                 Admon
# 13                             Nivel                                 Admon
# 14                             Nivel                                 Admon
# 15                             Nivel                                 Admon
# 16                             Nivel                                 Admon
# 17                             Nivel                                 Admon
# 18                             Nivel                                 Admon
# 19                             Nivel                                 Admon
#
#     Parcela catastral del numero      Tipologia del numero  \
# 0                                 Parcela
# 1                                 Parcela
# 2                                 Parcela
# 3                                 Parcela
# 4                                 Parcela
# 5                 4339503VK4483H  Parcela
# 6                                 Parcela
# 7                                 Parcela
# 8                                 Parcela
# 9                                 Parcela
# 10                7087502VK4768D  Parcela
# 11                                Parcela
# 12                                Parcela
# 13                                Parcela
# 14                                Parcela
# 15                                Parcela
# 16                                Parcela
# 17                                Parcela
# 18                                Parcela
# 19                                Parcela
#
#    Zona de valor del numero
# 0      R21S
# 1      R21N
# 2      R21S
# 3      R21R
# 4      R21O
# 5      R21N
# 6      RUSTICA
# 7      R21N
# 8      R15AB
# 9      R15AB
# 10     R24S
# 11     R23M
# 12     R24S
# 13     R23M
# 14     R24S
# 15     R23M
# 16     R26A
# 17     R23T
# 18     R20AB
# 19     R30E
#
# [20 rows x 26 columns]

# %%
df_1106 = direcciones.loc[direcciones['Codigo de via'] == 1106]
df_1106.head()
# Out:
#         Codigo de numero  Codigo de via           Clase de la via  \
# 118123          20058614           1106  GLORIETA
# 118124          20058617           1106  GLORIETA
#
#        Partï¿½cula de la vï¿½a  \
# 118123                  DE
# 118124                  DE
#
#                                       Nombre de la vï¿½a  \
# 118123  LUXEMBURGO
# 118124  LUXEMBURGO
#
#        Literal de numeracion  Codigo de distrito   Nombre del distrito  \
# 118123           NUM000002                    21  BARAJAS
# 118124           NUM000003                    21  BARAJAS
#
#         Codigo de barrio     Nombre del barrio  ...  \
# 118123                 5  CORRALEJOS            ...
# 118124                 5  CORRALEJOS            ...
#
#         Coordenada X (Guia Urbana) cm  Coordenada Y (Guia Urbana) cm  \
# 118123                       44755878                      447958681
# 118124                       44761742                      447953722
#
#        Longitud en S R  ETRS89 WGS84  Latitud en S R  ETRS89 WGS84  \
# 118123            3ï¿½37'11.46'' W              40ï¿½27'48.32'' N
# 118124            3ï¿½37'8.94'' W               40ï¿½27'46.71'' N
#
#         Tipo de la via a la que pertenece el numero  \
# 118123                            Vï¿½a
# 118124                            Vï¿½a
#
#        Situacion de la via respecto al terreno  \
# 118123                             Nivel
# 118124                             Nivel
#
#         Tipo de denominacion de la via  Parcela catastral del numero  \
# 118123                           Pleno                7801101VK4779H
# 118124                           Pleno                7593101VK4779D
#
#             Tipologia del numero Zona de valor del numero
# 118123  Frente fachada               R18L
# 118124  Parcela                      R18L
#
# [2 rows x 26 columns]

# %%
df_1106_2 = cruces.loc[cruces['Codigo de vía tratado'] == 1106]
df_1106_2.head()
# Out:
#      Codigo de vía tratado                  Literal completo del vial tratado  \
# 771                   1106  GLORIETA DE LUXEMBURGO                        ...
# 772                   1106  GLORIETA DE LUXEMBURGO                        ...
#
#       Clase de la via tratado Particula de la via tratado  \
# 771  GLORIETA                                      DE
# 772  GLORIETA                                      DE
#
#                              Nombre de la via tratado  \
# 771  LUXEMBURGO
# 772  LUXEMBURGO
#
#      Codigo de via que cruza o enlaza  \
# 771                              1112
# 772                              1111
#
#                    Literal completo del vial que cruza  \
# 771  AVENIDA DEL PARTENÓN                          ...
# 772  CALLE DE LA RIBERA DEL SENA                   ...
#
#     Clase de la via que cruza Particula de la via que cruza  \
# 771  AVENIDA                                         DEL
# 772  CALLE                                           DE LA
#
#                            Nombre de la via que cruza  \
# 771  PARTENON
# 772  RIBERA DEL SENA
#
#      Coordenada X (Guia Urbana) cm (cruce)  \
# 771                               44757499
# 772                               44756547
#
#      Coordenada Y (Guia Urbana) cm (cruce) Longitud en S R  WGS84 (cruce)  \
# 771                              447955328               3º37'10.77'' W
# 772                              447954264               3º37'11.15'' W
#
#     Latitud en S R  WGS84 (cruce)
# 771              40º27'47.22'' N
# 772              40º27'46.9'' N

# %%
import grafo as gf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import time, os, sys

# creamos una clase vertice que dado el atributo coordenadas, 
# si tiene las mismas coordenadas considere que es el mismo objeto
# es decir que tenga el mismo hash
class Vertice:
    def __init__(self, coords, num):
        self.calles = {}                    # Diccionario de calles: {calle: numero}
        self.coords = coords
        self.num = num

    def __hash__(self):
        return hash(self.coords)

    def __eq__(self, other):
        # esto lo que hace es que si dos vertices tienen las mismas coordenadas
        # se consideran iguales y por tanto tienen el mismo hash
        try:
            eq = (self.coords == other.coords)
        except:
            eq = False
            
        return eq

    def __repr__(self):
        return str(self.num)


grafo1 = gf.Grafo(False)                    # Grafo donde los pesos son las distancias
grafo2 = gf.Grafo(False)                    # Grafo donde los pesos son los tiempos
VELOCIDADES = {
        'AUTOVIA': 100,'AVENIDA': 90,'CARRETERA': 70,'CALLEJON': 30,'CAMINO': 30,
        'ESTACION DE METRO': 20, 'PASADIZO': 20, 'PLAZUELA': 20, 'COLONIA': 20
        }

def velocidad(tipo):
    if tipo in VELOCIDADES.keys():
        return VELOCIDADES[tipo]
    else:
        return 50


def unificar_rotondas_1(rotonda, df):
    # cogemos las coordenadas que componen la rotonda y las unimos en una unica
    # coordenada que será la media
    coords = (df[df['Codigo de vía tratado'] == rotonda]['Coordenada X (Guia Urbana) cm (cruce)'].mean(), df[df['Codigo de vía tratado'] == rotonda]['Coordenada Y (Guia Urbana) cm (cruce)'].mean())
    df.loc[df['Codigo de vía tratado'] == rotonda, 'Coordenada X (Guia Urbana) cm (cruce)'] = coords[0]
    df.loc[df['Codigo de vía tratado'] == rotonda, 'Coordenada Y (Guia Urbana) cm (cruce)'] = coords[1]
    return df, coords

def unificar_rotondas_2(rotonda, df):
    # cogemos las coordenadas que componen la rotonda y las unimos en una unica
    # coordenada que será la media
    df.loc[df['Codigo de via'] == rotonda, 'Coordenada X (Guia Urbana) cm'] = df[df['Codigo de via'] == rotonda]['Coordenada X (Guia Urbana) cm'].mean()
    df.loc[df['Codigo de via'] == rotonda, 'Coordenada Y (Guia Urbana) cm'] = df[df['Codigo de via'] == rotonda]['Coordenada Y (Guia Urbana) cm'].mean()
    return df


def ordenar_csv():  

    """
    ORDENAR CSV:
        - Leer cruces y direcciones y ordenar por numero de via
        - Para cada fila de cruces, su numero será la coordenada mas cercana del de direcciones
    """
    cruces = pd.read_csv('cruces.csv', sep=';', encoding='latin-1')
    direcciones = pd.read_csv('direcciones.csv', sep=';', encoding='latin-1', low_memory=False)
    cruces = cruces.sort_values(by=['Codigo de vía tratado','Codigo de via que cruza o enlaza'] )
    direcciones = direcciones.sort_values(by=['Codigo de via'] )

    
    vertices = {}                           # Diccionario de vertices: {coordenadas: objeto vertice (info)}
    calle_act = 127                         # Calle actual siendo procesada
    tipo_via = list(cruces.itertuples())[0][3]    # Tipo de via de la calle actual
    nombre_calle = list(cruces.itertuples())[0][5]    # Nombre de la calle actual
    dict_vertices = {}
    actualizar = False

    """
    GENERAR GRAFOS:
        - Procesar el fichero por filas procesando cada calle
        - Si las coordenadas de dicha fila no se encuntran en el diccionario
        de vértices, añadimos un nuevo vértice para estas
        - Empleamos el fichero de direcciones para asignar el número de la 
        coordenada más cercana
    """
    num_vertice = 0
    for fila in cruces.itertuples():

        calle = fila[1]
        coords = (fila[11], fila[12])  

        if 'GLORIETA' in fila[3]:
            # unificamos las coordenadas de la rotonda
            cruces, coords = unificar_rotondas_1(calle, cruces)
            direcciones = unificar_rotondas_2(calle, direcciones)
            
    
        if coords not in vertices:
            # agrgamos el vertice
            v = Vertice(coords, num_vertice)
            vertices[coords] = v
            grafo1.agregar_vertice(v)
            grafo2.agregar_vertice(v)
            num_vertice += 1

        # Asignar nº de coordenada más cercana
        menor_dist_calle = np.inf
        numero_calle = 0
        df_temporal = direcciones.loc[direcciones['Codigo de via'] == calle]

        for fila2 in df_temporal.itertuples():
    
            try:
                dist = np.sqrt((coords[0] - int(fila2[17]))**2 + (coords[1] - int(fila2[18]))**2)
                if dist < menor_dist_calle:
                    menor_dist_calle = dist
                    numero_calle = int(''.join(i for i in fila2[6] if i.isdigit()))
            except:
                pass

            if menor_dist_calle < 1500:
                #print('menor distancia', menor_dist_calle)
                # si esta muy cerca le asigno esos numeros
                break

        # añadimos el numero de calle a la lista de calles del vertice
        vertices[coords].calles[calle] = numero_calle

        """
        ORDENAR POR NÚMERO:
        - Al pasar a la siguiente calle dentro del fichero de cruces,
        se deben ordenar los vértices de la calle por clave
        - Una vez ordenadas, generar las aristas
        """
        # si estamos en el ultimo vertice del csv o cambiamos de calle
        # agregamos las aristas de esa calle
        if (fila[0] == len(cruces) - 1) or (calle_act != calle):
    
            dict_vertices = dict(sorted(dict_vertices.items(), key=lambda item: item[0]))
            v = list(dict_vertices.values())[0] # el anterior, para despues enlazarlos

            # cogemos desde la segunda hasta el final
            for u in list(dict_vertices.values())[1:]:
                # calcular distancia y agregamos la arista al grafo 1
                distancia = np.sqrt((v.coords[0] - u.coords[0])**2 + (v.coords[1] - u.coords[1])**2)
                if distancia < 600000 and v != u:
                    grafo1.agregar_arista(v,u, {'distancia': distancia, 'calle': nombre_calle, 'num_calle':calle_act, 'velocidad': velocidad(tipo_via)} ,distancia)
                    grafo1.agregar_arista(u,v, {'distancia': distancia, 'calle': nombre_calle, 'num_calle':calle_act, 'velocidad': velocidad(tipo_via)}, distancia)
                    
                    # dividimos la distancia entre la velocidad de la calle y lo multiplicamos por 60 para obtener los minutos
                    # agregamos la arista al grafo 2
                    tiempo = distancia / velocidad(tipo_via) * 60
                    grafo2.agregar_arista(v, u,  {'distancia': distancia, 'calle': nombre_calle, 'num_calle':calle_act, 'velocidad': velocidad(tipo_via)}, tiempo)
                    grafo2.agregar_arista(u, v,  {'distancia': distancia, 'calle': nombre_calle, 'num_calle':calle_act, 'velocidad': velocidad(tipo_via)}, tiempo)
                 
                v = u
        
            tipo_via = fila[3]
            calle_act = calle
            dict_vertices = {}
            dict_vertices[numero_calle] = vertices[coords]
            nombre_calle = fila[2]

        else:
            # en caso contrario segumos añadiendo vertices
            #  a la calle actual
            dict_vertices[numero_calle] = vertices[coords]

    return grafo1, grafo2

def pasar_network_x(grafo, nombre):
    G = nx.Graph()
    G.add_nodes_from([(v.num, {'coordenadas': v.coords}) for v in list(grafo.vertices.keys())])
    # en el grafo guardamos en cada vertice todas las aristas que pasan por el, concatenamos todas 
    # estas listas y hacemos un set para eliminar duplicados
    aristas = set([a for v in grafo.vertices.keys() for a in grafo.vertices[v]])
    G.add_edges_from([(a.origen.num, a.destino.num, {'distancia': a.data['distancia'], 'calle': a.data['calle'], 'numero_calle': a.data['num_calle']}) for a in aristas])
    pos = nx.get_node_attributes(G, 'coordenadas')
    plt.figure(figsize=(100,100))
    # ponemos las labels a las aristas (con el numero de la calle)
    nx.draw(G, pos=pos, with_labels=True, font_size=5, node_size=10)
    # vamos a resaltar l
    labels = nx.get_edge_attributes(G,'num_calle')
    nx.draw_networkx_edge_labels(G, pos=pos, edge_labels=labels, font_size=5)
    # guardamos la figura
    plt.savefig(nombre)


def iniciar():
    # leemos los csv, los ordenamos y creamos el grafo
    print('\nCargando grafos...')
    i = time.time()
    grafo1, grafo2 = ordenar_csv()
    f = time.time()
    print(f'Grafos cargados correctamente en {f-i} secs\n')
    return grafo1, grafo2


def encontrar_coordenadas_grafo(grafo, coordenadas):
    # buscamos las coordenadas mas cercanas de nuestro grafo a las insertadas
    # para ello calculamos la distancia de cada vertice a las coordenadas
    # y nos quedamos con el minimo
    minimo = np.inf
    for v in grafo.vertices.keys():
        distancia = np.sqrt((v.coords[0] - coordenadas[0])**2 + (v.coords[1] - coordenadas[1])**2)
        if distancia < minimo:
            minimo = distancia
            vertice = v
    return vertice


def Menu(grafo1, grafo2):
    # limipamos la pantalla
    print('\n------------      BIENVENIDO AL GPS BROSKI      ----------------\n')
    salir = False
    while not salir:
        print('Introduce las coordenadas (en cm) de origen y destino para calcular la ruta más corta')
        coordenadas_incorrectas = True
        # seguiremos preguntando por coordenadas hasta que el usuario decida salir que será cuando
        # no introduzca coordenadas de origen o destino
        while coordenadas_incorrectas:
            try:
                origen = input('Origen: ').strip()
                destino = input('Destino: ').strip()

                if '' in [origen, destino]:
                    # salimo del programa
                    coordenadas_incorrectas = False
                    salir = True
                else:
                    origen = [float(i) for i in origen.split(',')]
                    destino = [float(i) for i in destino.split(',')]

                    if len(origen) != 2 or len(destino) != 2:
                        raise ValueError
                    coordenadas_incorrectas = False
            except ValueError:
                print('Coordenadas invalidas, intentelo de nuevo')
        
        if not salir:
            # calculamos la ruta mas corta, primero preguntamos si prefieren distancia o tiempo
            print('¿Quieres calcular la ruta más corta en distancia o más rápida en tiempo?')
            print('1. Más corta')
            print('2. Más rápida')
            opcion = 0
            while opcion not in [1, 2]:
                try:
                    opcion = int(input('Opcion: '))
                    if opcion not in [1, 2]:
                        raise ValueError
                except ValueError:
                    print('Opcion invalida, intentelo de nuevo')
                except KeyboardInterrupt:
                    salir = True
                    break

            if not salir:
                if opcion == 1:          # distancia
                    grafo = grafo1
                else:                    # tiempo
                    grafo = grafo2
                
                # buscamos la ruta mas corta aplicando el algoritmo de dijkstra
                origen = encontrar_coordenadas_grafo(grafo, origen)
                destino = encontrar_coordenadas_grafo(grafo, destino)

                ruta = grafo.camino_minimo(origen, destino)
                print('La ruta más corta es: ')
                for i in range(len(ruta)-1):
                    print(f'{i+1}. Numero {ruta[i].num}, {ruta[i].calles}')

                



grafo1, grafo2 = iniciar()
# Menu(grafo1, grafo2)
# Out:
# Cargando grafos...
# Grafos cargados correctamente en 237.58129501342773 secs

# %%
origen = (44305633, 448250340)
destino = (44592921, 446971597)
origen = encontrar_coordenadas_grafo(grafo1, origen)
destino = encontrar_coordenadas_grafo(grafo1, destino)

ruta = grafo1.camino_minimo(origen, destino)
print('La ruta más corta es: ')
for i in range(len(ruta)-1):
    print(f'{i+1}. Numero {ruta[i].num}, {ruta[i].calles}')
# Out:
# Entramos a camino minimo
# Vamos a ir desde las coordenadas (44309892, 448247232) hasta las coordenadas (44592921, 446971597)
# La longitud de Q es 1
# La longitud de Q es 3
# La longitud de Q es 4
# La longitud de Q es 5
# La longitud de Q es 6
# La longitud de Q es 7
# La longitud de Q es 7
# La longitud de Q es 8
# La longitud de Q es 9
# La longitud de Q es 10
# La longitud de Q es 9
# La longitud de Q es 9
# La longitud de Q es 10
# La longitud de Q es 9
# La longitud de Q es 8
# La longitud de Q es 8
# La longitud de Q es 8
# La longitud de Q es 8
# La longitud de Q es 8
# La longitud de Q es 7
# La longitud de Q es 6
# La longitud de Q es 5
# La longitud de Q es 4
# La longitud de Q es 4
# La longitud de Q es 3
# La longitud de Q es 4
# La longitud de Q es 5
# La longitud de Q es 4
# La longitud de Q es 7
# La longitud de Q es 6
# La longitud de Q es 5
# La longitud de Q es 5
# La longitud de Q es 6
# La longitud de Q es 6
# La longitud de Q es 6
# La longitud de Q es 5
# La longitud de Q es 5
# La longitud de Q es 5
# La longitud de Q es 6
# La longitud de Q es 7
# La longitud de Q es 8
# La longitud de Q es 8
# La longitud de Q es 10
# La longitud de Q es 10
# La longitud de Q es 10
# La longitud de Q es 12
# La longitud de Q es 12
# La longitud de Q es 12
# La longitud de Q es 13
# La longitud de Q es 13
# La longitud de Q es 14
# La longitud de Q es 14
# La longitud de Q es 15
# La longitud de Q es 16
# La longitud de Q es 18
# La longitud de Q es 19
# La longitud de Q es 19
# La longitud de Q es 18
# La longitud de Q es 19
# La longitud de Q es 20
# La longitud de Q es 19
# La longitud de Q es 19
# La longitud de Q es 20
# La longitud de Q es 20
# La longitud de Q es 20
# La longitud de Q es 21
# La longitud de Q es 22
# La longitud de Q es 22
# La longitud de Q es 22
# La longitud de Q es 24
# La longitud de Q es 23
# La longitud de Q es 24
# La longitud de Q es 23
# La longitud de Q es 23
# La longitud de Q es 24
# La longitud de Q es 24
# La longitud de Q es 26
# La longitud de Q es 25
# La longitud de Q es 27
# La longitud de Q es 27
# La longitud de Q es 27
# La longitud de Q es 29
# La longitud de Q es 30
# La longitud de Q es 30
# La longitud de Q es 30
# La longitud de Q es 31
# La longitud de Q es 31
# La longitud de Q es 31
# La longitud de Q es 31
# La longitud de Q es 30
# La longitud de Q es 29
# La longitud de Q es 29
# La longitud de Q es 28
# La longitud de Q es 29
# La longitud de Q es 93
# La longitud de Q es 92
# La longitud de Q es 92
# La longitud de Q es 94
# La longitud de Q es 96
# La longitud de Q es 96
# La longitud de Q es 95
# La longitud de Q es 94
# La longitud de Q es 93
# La longitud de Q es 92
# La longitud de Q es 91
# La longitud de Q es 90
# La longitud de Q es 90
# La longitud de Q es 89
# La longitud de Q es 88
# La longitud de Q es 87
# La longitud de Q es 87
# La longitud de Q es 87
# La longitud de Q es 88
# La longitud de Q es 87
# La longitud de Q es 87
# La longitud de Q es 86
# La longitud de Q es 85
# La longitud de Q es 84
# La longitud de Q es 84
# La longitud de Q es 84
# Hemos llegado al destino
# La ruta más corta es:
# 1. Numero 5903, {118600: 118, 459550: 2}
# 2. Numero 4702, {78700: 348, 459550: 40, 31000470: 13}
# 3. Numero 4682, {78700: 339, 31000470: 61}
# 4. Numero 4668, {78700: 333, 364250: 8}
# 5. Numero 4647, {78700: 325, 125450: 116}
# 6. Numero 80, {746: 4, 78700: 324}
# 7. Numero 78, {742: 11, 78700: 321, 204150: 31}
# 8. Numero 87, {758: 10, 78700: 314, 125450: 3}
# 9. Numero 4669, {78700: 312, 391100: 4, 676900: 89}
# 10. Numero 4684, {78700: 289, 483800: 1}
# 11. Numero 4697, {78700: 287, 629800: 3}
# 12. Numero 4665, {78700: 281, 339700: 1, 608300: 1}
# 13. Numero 4676, {78700: 278, 424300: 1, 710400: 1}
# 14. Numero 3353, {35700: 1, 78700: 275, 674350: 8}
# 15. Numero 4649, {78700: 267, 97000: 2, 631200: 1}
# 16. Numero 4698, {78700: 261, 681500: 1}
# 17. Numero 4127, {63100: 2, 78700: 253}
# 18. Numero 4666, {78700: 247, 340300: 19}
# 19. Numero 4683, {78700: 241, 467100: 1}
# 20. Numero 4694, {78700: 240, 597500: 1}
# 21. Numero 2924, {22900: 1, 78700: 235, 80400: 1}
# 22. Numero 4674, {78700: 226, 421000: 2}
# 23. Numero 4658, {78700: 220, 262500: 2}
# 24. Numero 4656, {78700: 214, 254600: 1}
# 25. Numero 3200, {30800: 12, 78700: 209, 264300: 1}
# 26. Numero 4691, {78700: 201, 530900: 1, 555500: 17}
# 27. Numero 4678, {78700: 200, 441300: 366}
# 28. Numero 4701, {78700: 197, 781200: 17}
# 29. Numero 4652, {78700: 196, 135400: 13}
# 30. Numero 4688, {78700: 194}
# 31. Numero 4700, {78700: 190, 701800: 2}
# 32. Numero 4642, {78400: 17, 78700: 175, 99500: 2}
# 33. Numero 4653, {78700: 163, 161300: 19, 464900: 1}
# 34. Numero 4672, {78700: 159, 407700: 1}
# 35. Numero 4677, {78700: 157, 431900: 37}
# 36. Numero 3791, {50900: 1, 78700: 149}
# 37. Numero 4679, {78700: 148, 442400: 1, 467200: 16}
# 38. Numero 2206, {7000: 89, 169200: 17, 467200: 1}
# 39. Numero 2214, {7000: 81, 465100: 2}
# 40. Numero 18, {600: 1, 7000: 77}
# 41. Numero 2215, {7000: 72, 628100: 13}
# 42. Numero 13843, {628100: 26, 748600: 66}
# 43. Numero 12447, {491850: 46, 748600: 54}
# 44. Numero 4992, {87750: 60, 748600: 39}
# 45. Numero 10053, {330300: 1, 748600: 38}
# 46. Numero 11480, {417600: 3, 748600: 1, 792600: 10, 794400: 9, 796700: 58}
# 47. Numero 14595, {792600: 8, 794900: 9}
# 48. Numero 14597, {792600: 6, 795700: 23}
# 49. Numero 14588, {792500: 20, 792600: 4}
# 107. Numero 13015, {539900: 6, 616600: 10}
# 108. Numero 12148, {467300: 16, 539900: 2, 615100: 2}
# 109. Numero 13714, {615100: 6, 718450: 24}
# 110. Numero 13481, {587700: 24, 615100: 12}
# 111. Numero 13713, {615100: 20, 618600: 11}
# 112. Numero 13715, {615100: 38, 720575: 9}
# 113. Numero 14349, {720575: 8, 720900: 27}
# 114. Numero 10745, {364900: 180, 672700: 1, 720900: 1}
# 115. Numero 8, {150: 16, 364900: 155}

# %%
print('La ruta más corta es: ')
for i in range(len(ruta)-1):
    print(f'{i+1}. Numero {ruta[i].num}, {ruta[i].calles}')
# Out:
# La ruta más corta es:
# 1. Numero 5903, {118600: 118, 459550: 2}
# 2. Numero 4702, {78700: 348, 459550: 40, 31000470: 13}
# 3. Numero 4682, {78700: 339, 31000470: 61}
# 4. Numero 4668, {78700: 333, 364250: 8}
# 5. Numero 4647, {78700: 325, 125450: 116}
# 6. Numero 80, {746: 4, 78700: 324}
# 7. Numero 78, {742: 11, 78700: 321, 204150: 31}
# 8. Numero 87, {758: 10, 78700: 314, 125450: 3}
# 9. Numero 4669, {78700: 312, 391100: 4, 676900: 89}
# 10. Numero 4684, {78700: 289, 483800: 1}
# 11. Numero 4697, {78700: 287, 629800: 3}
# 12. Numero 4665, {78700: 281, 339700: 1, 608300: 1}
# 13. Numero 4676, {78700: 278, 424300: 1, 710400: 1}
# 14. Numero 3353, {35700: 1, 78700: 275, 674350: 8}
# 15. Numero 4649, {78700: 267, 97000: 2, 631200: 1}
# 16. Numero 4698, {78700: 261, 681500: 1}
# 17. Numero 4127, {63100: 2, 78700: 253}
# 18. Numero 4666, {78700: 247, 340300: 19}
# 19. Numero 4683, {78700: 241, 467100: 1}
# 20. Numero 4694, {78700: 240, 597500: 1}
# 21. Numero 2924, {22900: 1, 78700: 235, 80400: 1}
# 22. Numero 4674, {78700: 226, 421000: 2}
# 23. Numero 4658, {78700: 220, 262500: 2}
# 24. Numero 4656, {78700: 214, 254600: 1}
# 25. Numero 3200, {30800: 12, 78700: 209, 264300: 1}
# 26. Numero 4691, {78700: 201, 530900: 1, 555500: 17}
# 27. Numero 4678, {78700: 200, 441300: 366}
# 28. Numero 4701, {78700: 197, 781200: 17}
# 29. Numero 4652, {78700: 196, 135400: 13}
# 30. Numero 4688, {78700: 194}
# 31. Numero 4700, {78700: 190, 701800: 2}
# 32. Numero 4642, {78400: 17, 78700: 175, 99500: 2}
# 33. Numero 4653, {78700: 163, 161300: 19, 464900: 1}
# 34. Numero 4672, {78700: 159, 407700: 1}
# 35. Numero 4677, {78700: 157, 431900: 37}
# 36. Numero 3791, {50900: 1, 78700: 149}
# 37. Numero 4679, {78700: 148, 442400: 1, 467200: 16}
# 38. Numero 2206, {7000: 89, 169200: 17, 467200: 1}
# 39. Numero 2214, {7000: 81, 465100: 2}
# 40. Numero 18, {600: 1, 7000: 77}
# 41. Numero 2215, {7000: 72, 628100: 13}
# 42. Numero 13843, {628100: 26, 748600: 66}
# 43. Numero 12447, {491850: 46, 748600: 54}
# 100. Numero 11160, {394300: 18, 588800: 5}
# 101. Numero 13495, {588800: 2, 716900: 1}
# 102. Numero 14320, {713600: 3, 716900: 6}
# 103. Numero 13506, {591400: 6, 716900: 9}
# 104. Numero 2034, {2872: 36, 591400: 2}
# 105. Numero 2031, {2872: 40, 461300: 2}
# 106. Numero 12099, {461300: 10, 616600: 8}
# 107. Numero 13015, {539900: 6, 616600: 10}
# 108. Numero 12148, {467300: 16, 539900: 2, 615100: 2}
# 109. Numero 13714, {615100: 6, 718450: 24}
# 110. Numero 13481, {587700: 24, 615100: 12}
# 111. Numero 13713, {615100: 20, 618600: 11}
# 112. Numero 13715, {615100: 38, 720575: 9}
# 113. Numero 14349, {720575: 8, 720900: 27}
# 114. Numero 10745, {364900: 180, 672700: 1, 720900: 1}
# 115. Numero 8, {150: 16, 364900: 155}

# %%
def pintar_grafo(grafo, ruta, nombre):
    G = nx.Graph()
    G.add_nodes_from([(v.num, {'coordenadas': v.coords}) for v in list(grafo.vertices.keys())])
    aristas = set([a for v in grafo.vertices.keys() for a in grafo.vertices[v]])
    G.add_edges_from([(a.origen.num, a.destino.num, {'distancia': a.data['distancia'], 'calle': a.data['calle'], 'numero_calle': a.data['num_calle']}) for a in aristas])
    pos = nx.get_node_attributes(G, 'coordenadas')
    plt.figure(figsize=(100,100))
    # ponemos las labels a las aristas (con el numero de la calle)
    nx.draw(G, pos=pos, with_labels=True, font_size=5, node_size=10)
    # vamos a resaltar l
    labels = nx.get_edge_attributes(G,'num_calle')
    nx.draw_networkx_edge_labels(G, pos=pos, edge_labels=labels, font_size=5)

    # resaltamos los nodos y las aristas de la ruta
    nx.draw_networkx_nodes(G, pos=pos, nodelist=[v.num for v in ruta], node_color='r', node_size=70)
    nx.draw_networkx_edges(G, pos=pos, edgelist=[(a.origen.num, a.destino.num) for a in aristas if a in ruta], edge_color='red', width=20)
    plt.savefig(nombre)

    
# pintamos el grafo y resaltamos los nodos y las aristas de la ruta
pintar_grafo(grafo1, ruta, 'grafo1.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/lara/Library/CloudStorage/OneDrive-UniversidadPontificiaComillas/segundo_imat_mac/matematica_discreta/GPS/explorarficheros.ipynb Celda 12 in <cell line: 21>()
#      <a href='vscode-notebook-cell:/Users/lara/Library/CloudStorage/OneDrive-UniversidadPontificiaComillas/segundo_imat_mac/matematica_discreta/GPS/explorarficheros.ipynb#X14sZmlsZQ%3D%3D?line=16'>17</a>     plt.savefig(nombre)
#      <a href='vscode-notebook-cell:/Users/lara/Library/CloudStorage/OneDrive-UniversidadPontificiaComillas/segundo_imat_mac/matematica_discreta/GPS/explorarficheros.ipynb#X14sZmlsZQ%3D%3D?line=19'>20</a> # pintamos el grafo y resaltamos los nodos y las aristas de la ruta
# ---> <a href='vscode-notebook-cell:/Users/lara/Library/CloudStorage/OneDrive-UniversidadPontificiaComillas/segundo_imat_mac/matematica_discreta/GPS/explorarficheros.ipynb#X14sZmlsZQ%3D%3D?line=20'>21</a> pintar_grafo(grafo1, ruta, 'grafo1.png')
#
# NameError: name 'grafo1' is not defined
